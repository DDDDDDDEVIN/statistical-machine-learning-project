# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

# stdlib / third-party imports still used by the scratch cell below
import torch
import json
from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence

# shared, de-duplicated implementations
from src.baselines import (
    TextDataset, DataFactory, mmd_loss,
    BertBaseline, MLPBaseline, BERTClassifier, RoBERTaClassifier,
    Classifier, Main,
)

# %%
class Config:
    lambda_mmd = 0.001
    name = 'MLP_baseline'
    model_cls = MLPBaseline
    embed_dim = 256
    num_heads = 16
    hidden_dim = 512
    num_layers = 2
    num_classes = 2
    path1 = '../data/raw/domain1_train_data.json'
    path2 = '../data/raw/domain2_train_data.json'
    test_path = '../data/raw/test_data.json'
    num_epochs = 15
    batch_size1 = 32
    batch_size2 = 32
    seed = 42
    tau=1
    save_path = "../results/mlp_baseline_predictions.csv"

configs = Config()
main = Main(configs)

# %%
main.train()
# Out:
# 0it [00:00, ?it/s]
# 3it [00:00, 28.41it/s]
# 6it [00:00, 27.58it/s]
# 9it [00:00, 28.39it/s]
# 12it [00:00, 28.25it/s]
# 16it [00:00, 29.00it/s]
# 20it [00:00, 29.57it/s]
# 22it [00:00, 28.77it/s]
# Epoch   1, Loss: 0.6264, Accuracy: 0.7293, F1: 0.4212
# 0it [00:00, ?it/s]
# 10it [00:00, 108.70it/s]
# Validation Loss: 0.5963, Accuracy: 0.7240, F1: 0.4195
# 0it [00:00, ?it/s]
# 3it [00:00, 28.57it/s]
# 6it [00:00, 28.79it/s]
# 10it [00:00, 29.46it/s]
# 13it [00:00, 29.54it/s]
# 16it [00:00, 29.50it/s]
# 20it [00:00, 29.72it/s]
# 22it [00:00, 29.50it/s]
# Epoch   2, Loss: 0.5883, Accuracy: 0.7188, F1: 0.4288
# 0it [00:00, ?it/s]
# 10it [00:00, 102.04it/s]
# Validation Loss: 0.5743, Accuracy: 0.7348, F1: 0.4917
# 0it [00:00, ?it/s]
# 3it [00:00, 28.57it/s]
# 6it [00:00, 29.06it/s]
# 9it [00:00, 29.22it/s]
# 12it [00:00, 28.42it/s]
# 15it [00:00, 28.52it/s]
# 18it [00:00, 28.63it/s]
# 21it [00:00, 28.52it/s]
# 22it [00:00, 28.67it/s]
# Epoch   3, Loss: 0.5670, Accuracy: 0.7402, F1: 0.5325
# 0it [00:00, ?it/s]
# 10it [00:00, 111.11it/s]
# Validation Loss: 0.5595, Accuracy: 0.7558, F1: 0.5627
# 0it [00:00, ?it/s]
# 3it [00:00, 28.57it/s]
# 6it [00:00, 29.39it/s]
# 9it [00:00, 29.53it/s]
# 12it [00:00, 29.26it/s]
# 15it [00:00, 29.52it/s]
# 18it [00:00, 29.29it/s]
# 21it [00:00, 29.33it/s]
# 22it [00:00, 29.33it/s]
# Epoch   4, Loss: 0.5419, Accuracy: 0.7707, F1: 0.5925
# 0it [00:00, ?it/s]
# 10it [00:00, 113.64it/s]
# Validation Loss: 0.5448, Accuracy: 0.7605, F1: 0.5813
# 0it [00:00, ?it/s]
# 3it [00:00, 27.52it/s]
# 6it [00:00, 28.13it/s]
# 9it [00:00, 28.70it/s]
# 12it [00:00, 28.54it/s]
# 15it [00:00, 28.75it/s]
# 18it [00:00, 29.07it/s]
# 21it [00:00, 29.37it/s]
# 22it [00:00, 28.95it/s]
# Epoch   5, Loss: 0.5296, Accuracy: 0.7703, F1: 0.6025
# 0it [00:00, ?it/s]
# 10it [00:00, 108.69it/s]
# Validation Loss: 0.5262, Accuracy: 0.7605, F1: 0.5838
# 0it [00:00, ?it/s]
# 3it [00:00, 28.08it/s]
# 6it [00:00, 28.37it/s]
# 9it [00:00, 28.71it/s]
# 12it [00:00, 28.55it/s]
# 16it [00:00, 29.55it/s]
# 19it [00:00, 29.42it/s]
# 22it [00:00, 29.24it/s]
# 22it [00:00, 29.03it/s]
# Epoch   6, Loss: 0.5015, Accuracy: 0.7844, F1: 0.6453
# 0it [00:00, ?it/s]
# 10it [00:00, 109.86it/s]
# Validation Loss: 0.4933, Accuracy: 0.7972, F1: 0.6858
# 0it [00:00, ?it/s]
# 3it [00:00, 29.70it/s]
# 7it [00:00, 30.24it/s]
# 11it [00:00, 29.73it/s]
# 14it [00:00, 29.52it/s]
# 17it [00:00, 29.20it/s]
# 21it [00:00, 29.79it/s]
# 22it [00:00, 29.69it/s]
# Epoch   7, Loss: 0.4798, Accuracy: 0.8156, F1: 0.7294
# 0it [00:00, ?it/s]
# 10it [00:00, 116.28it/s]
# Validation Loss: 0.4714, Accuracy: 0.8151, F1: 0.7206
# 0it [00:00, ?it/s]
# 3it [00:00, 29.83it/s]
# 6it [00:00, 29.25it/s]
# 10it [00:00, 30.03it/s]
# 13it [00:00, 29.80it/s]
# 16it [00:00, 29.08it/s]
# 19it [00:00, 28.66it/s]
# 22it [00:00, 29.24it/s]
# Epoch   8, Loss: 0.4428, Accuracy: 0.8498, F1: 0.7977
# 0it [00:00, ?it/s]
# 10it [00:00, 111.11it/s]
# Validation Loss: 0.4409, Accuracy: 0.8470, F1: 0.7862
# 0it [00:00, ?it/s]
# 3it [00:00, 28.57it/s]
# 6it [00:00, 29.06it/s]
# 10it [00:00, 29.59it/s]
# 14it [00:00, 29.89it/s]
# 17it [00:00, 29.83it/s]
# 20it [00:00, 29.70it/s]
# 22it [00:00, 29.53it/s]
# Epoch   9, Loss: 0.4173, Accuracy: 0.8547, F1: 0.8066
# 0it [00:00, ?it/s]
# 10it [00:00, 112.36it/s]
# Validation Loss: 0.4242, Accuracy: 0.8486, F1: 0.7908
# 0it [00:00, ?it/s]
# 3it [00:00, 30.00it/s]
# 7it [00:00, 30.50it/s]
# 11it [00:00, 30.07it/s]
# 15it [00:00, 30.26it/s]
# 19it [00:00, 29.94it/s]
# 22it [00:00, 29.79it/s]
# 22it [00:00, 29.93it/s]
# Epoch  10, Loss: 0.3910, Accuracy: 0.8769, F1: 0.8430
# 0it [00:00, ?it/s]
# 10it [00:00, 117.65it/s]
# Validation Loss: 0.4250, Accuracy: 0.8345, F1: 0.7615
# 0it [00:00, ?it/s]
# 3it [00:00, 29.13it/s]
# 6it [00:00, 28.32it/s]
# 9it [00:00, 28.62it/s]
# 13it [00:00, 29.48it/s]
# 17it [00:00, 29.89it/s]
# 21it [00:00, 30.12it/s]
# 22it [00:00, 29.63it/s]
# Epoch  11, Loss: 0.3513, Accuracy: 0.9030, F1: 0.8716
# 0it [00:00, ?it/s]
# 10it [00:00, 111.11it/s]
# Validation Loss: 0.4036, Accuracy: 0.8470, F1: 0.7894
# 0it [00:00, ?it/s]
# 3it [00:00, 29.41it/s]
# 7it [00:00, 29.84it/s]
# 10it [00:00, 29.54it/s]
# 13it [00:00, 29.71it/s]
# 16it [00:00, 29.71it/s]
# 19it [00:00, 29.80it/s]
# 22it [00:00, 29.77it/s]
# Epoch  12, Loss: 0.3397, Accuracy: 0.9009, F1: 0.8719
# 0it [00:00, ?it/s]
# 10it [00:00, 114.94it/s]
# Validation Loss: 0.3847, Accuracy: 0.8533, F1: 0.8014
# 0it [00:00, ?it/s]
# 3it [00:00, 29.70it/s]
# 6it [00:00, 29.36it/s]
# 9it [00:00, 29.12it/s]
# 12it [00:00, 29.35it/s]
# 15it [00:00, 29.48it/s]
# 18it [00:00, 29.55it/s]
# 22it [00:00, 29.33it/s]
# 22it [00:00, 29.33it/s]
# Epoch  13, Loss: 0.3212, Accuracy: 0.9026, F1: 0.8755
# 0it [00:00, ?it/s]
# 10it [00:00, 109.09it/s]
# Validation Loss: 0.3726, Accuracy: 0.8595, F1: 0.8152
# 0it [00:00, ?it/s]
# 3it [00:00, 29.70it/s]
# 6it [00:00, 29.36it/s]
# 9it [00:00, 29.65it/s]
# 12it [00:00, 29.67it/s]
# 16it [00:00, 29.75it/s]
# 19it [00:00, 29.55it/s]
# 22it [00:00, 29.42it/s]
# 22it [00:00, 29.53it/s]
# Epoch  14, Loss: 0.3028, Accuracy: 0.9087, F1: 0.8852
# 0it [00:00, ?it/s]
# 10it [00:00, 114.94it/s]
# Validation Loss: 0.3582, Accuracy: 0.8680, F1: 0.8303
# 0it [00:00, ?it/s]
# 3it [00:00, 28.57it/s]
# 7it [00:00, 30.27it/s]
# 11it [00:00, 30.29it/s]
# 15it [00:00, 30.39it/s]
# 19it [00:00, 30.19it/s]
# 22it [00:00, 30.18it/s]
# Epoch  15, Loss: 0.2852, Accuracy: 0.9132, F1: 0.8895
# 0it [00:00, ?it/s]
# 10it [00:00, 117.65it/s]
# Validation Loss: 0.3931, Accuracy: 0.8423, F1: 0.7756

# %%
# main.test()

# %%
PAD_ID = 0
CLS_ID = 0  # 如果你在训练时在序列前插了这个 CLS token

class TestDataset(Dataset):
    def __init__(self, path: str, max_len: int = 256):
        self.samples = []
        with open(path) as f:
            for line in f:
                obj = json.loads(line)
                # obj 里有 obj["text"] (List[int]) 和 obj["id"]
                tok = obj["text"][:max_len]
                self.samples.append({
                    "id":   obj["id"],
                    "tok":  tok
                })
    def __len__(self):
        return len(self.samples)
    def __getitem__(self, i):
        return self.samples[i]

def collate_test(batch):
    """
    batch: list of {"id": id, "tok": [..]}
    返回:
      padded:  LongTensor (B, L)
      mask:    LongTensor (B, L)
      ids:     LongTensor (B,)
    """
    seqs, ids = [], []
    for s in batch:
        seq = torch.tensor([CLS_ID] + s["tok"], dtype=torch.long)
        seqs.append(seq)
        ids.append(s["id"])
    padded = pad_sequence(seqs, batch_first=True, padding_value=PAD_ID)
    mask   = (padded != PAD_ID).long()
    return padded, mask, torch.tensor(ids, dtype=torch.long)
